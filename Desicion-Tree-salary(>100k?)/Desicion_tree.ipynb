# %% [markdown]
# <a href="https://colab.research.google.com/github/safaltasaxena/ml-learning-mini-projects/blob/main/Desicion-Tree-salary(%3E100k%3F)/Desicion_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Desicion Tree Classifier

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9793c6fe-282e-4283-9677-09375ab876c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9793c6fe-282e-4283-9677-09375ab876c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("tree.csv")
df
# Out:
#      company        job degree  salary
# 0     google  sales exe  btech       0
# 1     google  sales exe  mtech       0
# 2     google    bsn man  btech       1
# 3     google    bsn man  mtech       1
# 4     google    comp pr  btech       0
# 5     google    comp pr  mtech       1
# 6   abc phar  sales exe  mtech       0
# 7   abc phar    comp pr  btech       0
# 8   abc phar    bsn man  btech       0
# 9   abc phar    bsn man  mtech       1
# 10  facebook  sales exe  btech       1
# 11  facebook  sales exe  mtech       1
# 12  facebook    bsn man  btech       1
# 13  facebook    bsn man  mtech       1
# 14  facebook    comp pr  btech       1
# 15  facebook    comp pr  mtech       1

# %%
inputs = df.drop('salary',axis='columns')
target=df['salary']

# %%
inputs
# Out:
#      company        job degree
# 0     google  sales exe  btech
# 1     google  sales exe  mtech
# 2     google    bsn man  btech
# 3     google    bsn man  mtech
# 4     google    comp pr  btech
# 5     google    comp pr  mtech
# 6   abc phar  sales exe  mtech
# 7   abc phar    comp pr  btech
# 8   abc phar    bsn man  btech
# 9   abc phar    bsn man  mtech
# 10  facebook  sales exe  btech
# 11  facebook  sales exe  mtech
# 12  facebook    bsn man  btech
# 13  facebook    bsn man  mtech
# 14  facebook    comp pr  btech
# 15  facebook    comp pr  mtech

# %%
target
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# Name: salary, dtype: int64

# %% [markdown]
# we know ml ago can only work on numbers they cannot owrk on labels so we will convert all three coloumns of labels into numbers using label encoder.

# %%
from sklearn.preprocessing import LabelEncoder
le_company=LabelEncoder()
le_job=LabelEncoder()
le_degree=LabelEncoder()

# %%
inputs['company_n']=le_company.fit_transform(inputs['company'])
inputs['job_n']=le_job.fit_transform(inputs['job'])
inputs['degree_n']=le_degree.fit_transform(inputs['degree'])
inputs.head()
# Out:
#   company        job degree  company_n  job_n  degree_n
# 0  google  sales exe  btech          2      2         0
# 1  google  sales exe  mtech          2      2         1
# 2  google    bsn man  btech          2      0         0
# 3  google    bsn man  mtech          2      0         1
# 4  google    comp pr  btech          2      1         0

# %%
inputs_n = inputs.drop(['company','job','degree'],axis='columns')
inputs_n
# Out:
#     company_n  job_n  degree_n
# 0           2      2         0
# 1           2      2         1
# 2           2      0         0
# 3           2      0         1
# 4           2      1         0
# 5           2      1         1
# 6           0      2         1
# 7           0      1         0
# 8           0      0         0
# 9           0      0         1
# 10          1      2         0
# 11          1      2         1
# 12          1      0         0
# 13          1      0         1
# 14          1      1         0
# 15          1      1         1

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n,target)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[2,2,1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
